# %% [markdown]
# # Тестовое задание в команду продуктовой аналитики, Gett.

# %% [markdown]
# В папке с заданием два датасета - data_orders - содержит выборку данных по заказам пользователей и включает такие колонки как:
# * order_datetime -  время заказа
# * origin_longitude - долгота
# * origin_latitude - широта
# * m_order_eta - время до прибытия машины
# * order_gk - номер заказа
# * order_status_key - статус (4 - отменен клиентом, 9 - отменен системой (reject))
# * is_driver_assigned_key - был ли назначен водитель
# * cancellations_time_in_seconds - сколько секунд прошло до отмены
#
# data_offers - содержит пары номер заказа - ID оффера, который был предложен водителю по данному заказу.

# %% [markdown]
# В момент когда клиент нажимать на кнопку "Заказать" в приложении, система матчинга подыскивает наиболее релевантых водителей и предлагаем им заказ. В задании предлагается исследовать некоторые метрики матчинга для заказов, которые не завершились успешно (клиент в итоге не получил машину).

# %% [markdown]
# # Импорт библиотек и загрузка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://github.com/slgero/testovoe/raw/master/Gett/data/data_orders.csv')
offers = pd.read_csv('https://github.com/slgero/testovoe/raw/master/Gett/data/data_offers.csv')

# %% [markdown]
# # Анализ данных

# %%
df.head()
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
#
#    cancellations_time_in_seconds
# 0                          198.0
# 1                          128.0
# 2                           46.0
# 3                           62.0
# 4                            NaN

# %% [markdown]
# **1.** Постройте распределение заказов по причинам неуспеха: отмены до и после назначения водителя, режекты

# %%
df.order_status_key.value_counts()
# Out:
# 4    7307
# 9    3409
# Name: order_status_key, dtype: int64

# %%
df.order_status_key.value_counts(normalize=True)
# Out:
# 4    0.681878
# 9    0.318122
# Name: order_status_key, dtype: float64

# %%
df.isna().mean()
# Out:
# order_datetime                   0.000000
# origin_longitude                 0.000000
# origin_latitude                  0.000000
# m_order_eta                      0.737402
# order_gk                         0.000000
# order_status_key                 0.000000
# is_driver_assigned_key           0.000000
# cancellations_time_in_seconds    0.318122
# dtype: float64

# %%
len(df.order_gk.value_counts()) == len(df) #все заказы уникальны
# Out:
# True

# %%
plot = df.groupby(['is_driver_assigned_key', 'order_status_key'])['order_gk'].count().reset_index()

# %%
plot
# Out:
#    is_driver_assigned_key  order_status_key  order_gk
# 0                       0                 4      4496
# 1                       0                 9      3406
# 2                       1                 4      2811
# 3                       1                 9         3

# %%
df[df['is_driver_assigned_key']==0]['order_status_key'].value_counts(normalize=True)
# Out:
# 4    0.56897
# 9    0.43103
# Name: order_status_key, dtype: float64

# %%
df[df['is_driver_assigned_key']==1]['order_status_key'].value_counts(normalize=True)
# Out:
# 4    0.998934
# 9    0.001066
# Name: order_status_key, dtype: float64

# %%
df['is_canceled_by_customer'] = (df['order_status_key'] == 4)*1

# %%
ax = sns.barplot(data=plot, x='order_status_key', y='order_gk', hue='is_driver_assigned_key')
ax.set_title('Распределение заказов по причинам неуспеха')
ax.set_ylabel('Количество заказов')
ax.set_xlabel('Категория')
# Out:
# Text(0.5, 0, 'Категория')

# %% [markdown]
# **2.** Постройте график распределения фейлов по часам - наблюдается ли тендеция, что в какие то часы доля той или иной категории аномально высока?

# %%
df.head()
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
#
#    cancellations_time_in_seconds  is_canceled_by_customer
# 0                          198.0                        1
# 1                          128.0                        1
# 2                           46.0                        1
# 3                           62.0                        1
# 4                            NaN                        0

# %%
df['hour'] = df['order_datetime'].str[:2]

# %%
client = df[df['order_status_key']==4].groupby('hour')['is_canceled_by_customer'].agg(['count'])

# %%
reject = df[df['order_status_key']==9].groupby('hour')['is_canceled_by_customer'].agg(['count'])

# %%
a = sns.lineplot(data=reject, x='hour', y = 'count', color = 'red')
b = sns.lineplot(data=client, x='hour', y = 'count', color = 'green')
a.set_xlabel('Часы')
a.set_ylabel('Количество заказов')
# Out:
# Text(0, 0.5, 'Количество заказов')

# %% [markdown]
# В 8 часов утра наблюдается резкий пик по отказам в обеих категориях

# %% [markdown]
# **3**. Постройте графики среднего времени до отмены (cancellations_time_in_seconds) с водителем и без, по часам. Можно ли сделать выводы по этому графику?

# %%
df.cancellations_time_in_seconds.hist()
# Out:
# <AxesSubplot:>

# %%
(df.cancellations_time_in_seconds>1000).mean()
#Выбросы составляют меньшую часть выборки
# Out:
# 0.006718924972004479

# %%
df.head()
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
#
#    cancellations_time_in_seconds  is_canceled_by_customer hour
# 0                          198.0                        1   18
# 1                          128.0                        1   20
# 2                           46.0                        1   12
# 3                           62.0                        1   13
# 4                            NaN                        0   21

# %%
df[df['cancellations_time_in_seconds']<=1000].groupby('is_driver_assigned_key')['cancellations_time_in_seconds'].agg(['mean', 'median', 'count'])
# Out:
#                               mean  median  count
# is_driver_assigned_key
# 0                       108.189087    88.0   4490
# 1                       205.276503   121.0   2745

# %%
with_driver = df[df['is_driver_assigned_key']==1].groupby('hour')['cancellations_time_in_seconds'].agg(['mean', 'median'])
without_driver = df[df['is_driver_assigned_key']==0].groupby('hour')['cancellations_time_in_seconds'].agg(['mean', 'median'])

# %%
c = with_driver['mean'].plot(kind='bar')
c.set_xlabel('Часы')
c.set_ylabel('Среднее время отмены с водителем')
#среднее время до отмены с водителем
# Out:
# Text(0, 0.5, 'Среднее время отмены с водителем')

# %%
e = without_driver['mean'].plot(kind='bar')
e.set_xlabel('Часы')
e.set_ylabel('Среднее время отмены без водителя')
#среднее время до отмены без водителем
# Out:
# Text(0, 0.5, 'Среднее время отмены без водителя')

# %%
without_d = without_driver['mean'].mean()
with_d = with_driver['mean'].mean()
print(f'Среднее время отмены если водителя назначили: {with_d}', f'Среднее время отмены если водителя не назначили: {without_d}', sep = '\n')
# Out:
# Среднее время отмены если водителя назначили: 242.6063235304107
# Среднее время отмены если водителя не назначили: 107.31176564166903

# %% [markdown]
# Если водитель не назначен, то время отмены меньше
#
# По часам время до отмены распределено практически равномерно

# %% [markdown]
# **4.** Постройте распределение среднего ЕТА по часам. Чем можно объяснить такой вид графика?

# %%
df.head()
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
#
#    cancellations_time_in_seconds  is_canceled_by_customer hour
# 0                          198.0                        1   18
# 1                          128.0                        1   20
# 2                           46.0                        1   12
# 3                           62.0                        1   13
# 4                            NaN                        0   21

# %%
df.m_order_eta.isna().mean()
# Out:
# 0.7374020156774916

# %%
ETA = df.groupby('hour')['m_order_eta'].agg(['mean', 'count', 'median']).reset_index()

# %%
d = sns.barplot(data=ETA, x='hour', y='median')
d.set_title('Распределение медианной ЕТА по часам')
d.set_ylabel('Медиана ЕТА')
d.set_xlabel('Часы')
# Out:
# Text(0.5, 0, 'Часы')

# %%
e = sns.barplot(data=ETA, x='hour', y='mean')
e.set_title('Распределение среднего ЕТА по часам')
e.set_ylabel('Среднее ЕТА')
e.set_xlabel('Часы')
# Out:
# Text(0.5, 0, 'Часы')

# %% [markdown]
# Время до прибытия машины значительно выше в утренние часы пик

# %% [markdown]
# 5. Колонка drivers_offered - показывает сколько водителей увидели заказ и могли его принять. Постройте часовую разбивку среднего количества водителей которым был предложен заказ. Что можно сказать по ней про избыток/нехватку водителей в те или иные часы?

# %%
offers_by_order.head()
# Out:
#         order_gk  offer_id
# 0  3000551431542         1
# 1  3000551431560         2
# 2  3000551431566         5
# 3  3000551431577         2
# 4  3000551431592         7

# %%
offers_by_order = offers.groupby('order_gk')['offer_id'].nunique().reset_index()

# %%
df = df.merge(offers_by_order, how='left', on='order_gk')

# %%
df['offer_id'] = df['offer_id'].fillna(0)

# %%
g = df['offer_id'].hist()
g.set_xlabel('Количество предложенных заказов')
g.set_ylabel('Частотость')
# Out:
# Text(0, 0.5, 'Частотость')

# %%
df.groupby('hour')['offer_id'].agg(['mean', 'count', 'median']).head()
# Out:
#           mean  count  median
# hour
# 00    2.918009    683     2.0
# 01    2.770701    471     2.0
# 02    2.657658    555     2.0
# 03    2.764133    513     2.0
# 04    1.493421    152     1.0

# %%
f = df.groupby('hour')['offer_id'].agg(['mean', 'count', 'median'])['mean'].plot(kind='bar')
f.set_xlabel('Часы')
f.set_ylabel('Среднее число увиденных заказов')
# Out:
# Text(0, 0.5, 'Среднее число увиденных заказов')

# %%
df['offer_id'].mean()
#Распределение водителей увидевших заказ, практически равномерное
#исключения - 4 и 5 часы утра, просадка почти в 2 раза, но это и самое метрвое время по колличесту заказов
# Out:
# 2.917879805897723

# %% [markdown]
# **6*.** Гексаконы.
# Воспользовавшись пакетами h3 и folium, посчитайте, сколько гексагонов размера 8 (https://uber.github.io/h3/#/documentation/core-library/resolution-table) содержат 80% всех заказов из исходного датасета и визуализируйте гексагон с наибольшим количеством фейлов на карте.

# %%
! pip install h3
# Out:
# Collecting h3
#   Downloading h3-3.7.6-cp39-cp39-win_amd64.whl (855 kB)
#      -------------------------------------- 855.6/855.6 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: h3
# Successfully installed h3-3.7.6

# %%
>>> import h3
>>> lat, lng = 37.769377, -122.388903
>>> resolution = 9
>>> h3.geo_to_h3(lat, lng, resolution)
# Out:
# '89283082e73ffff'

# %%
df.head()
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
#
#    cancellations_time_in_seconds  is_canceled_by_customer hour  offer_id
# 0                          198.0                        1   18       1.0
# 1                          128.0                        1   20       3.0
# 2                           46.0                        1   12       6.0
# 3                           62.0                        1   13       3.0
# 4                            NaN                        0   21       0.0

# %%
def get_gexagon(row):
  resolution = 8
  return h3.geo_to_h3(row['origin_latitude'], row['origin_longitude'], resolution)

# %%
df['gexagon'] = df.apply(get_gexagon, axis = 1)

# %%
gexagon = df['gexagon'].value_counts().reset_index()

# %%
len(df), gexagon['gexagon'].sum()
# Out:
# (10716, 10716)

# %%
gexagon['gexagon'] / gexagon['gexagon'].sum()
# Out:
# 0      0.139698
# 1      0.081187
# 2      0.072228
# 3      0.065976
# 4      0.062243
#          ...
# 139    0.000093
# 140    0.000093
# 141    0.000093
# 142    0.000093
# 143    0.000093
# Name: gexagon, Length: 144, dtype: float64

# %%
(gexagon['gexagon'].cumsum() / gexagon['gexagon'].sum()).head(25).tail(6)
# Out:
# 19    0.773143
# 20    0.781728
# 21    0.790220
# 22    0.798152
# 23    0.805711
# 24    0.813177
# Name: gexagon, dtype: float64

# %% [markdown]
# 24 гексагонов содержат 80 процентов всех заказов(в серии нумерация начинается с нуля)

# %%
24/144
# Out:
# 0.16666666666666666

# %% [markdown]
# # Визуализируйте гексагон с наибольшим количеством фейлов на карте.

# %%
df.head()
# Out:
#   order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0       18:08:07         -0.978916        51.456173         60.0
# 1       20:57:32         -0.950385        51.456843          NaN
# 2       12:07:50         -0.969520        51.455544        477.0
# 3       13:50:20         -1.054671        51.460544        658.0
# 4       21:24:45         -0.967605        51.458236          NaN
#
#         order_gk  order_status_key  is_driver_assigned_key  \
# 0  3000583041974                 4                       1
# 1  3000583116437                 4                       0
# 2  3000582891479                 4                       1
# 3  3000582941169                 4                       1
# 4  3000583140877                 9                       0
#
#    cancellations_time_in_seconds  is_canceled_by_customer hour  offer_id  \
# 0                          198.0                        1   18       1.0
# 1                          128.0                        1   20       3.0
# 2                           46.0                        1   12       6.0
# 3                           62.0                        1   13       3.0
# 4                            NaN                        0   21       0.0
#
#            gexagon
# 0  88195d2b03fffff
# 1  88195d2b19fffff
# 2  88195d2b1dfffff
# 3  88195d7497fffff
# 4  88195d2b1dfffff

# %%
df['fail'] = (df['order_status_key'] == 9)*1

# %%
df.groupby('gexagon')['fail'].sum().sort_values(ascending=False)
# Out:
# gexagon
# 88195d2b1dfffff    358
# 88195d2b1bfffff    256
# 88195d2b11fffff    225
# 88195d284dfffff    216
# 88195d2b15fffff    198
#                   ...
# 88195d2a1bfffff      0
# 88195d74d1fffff      0
# 88195d2807fffff      0
# 88195d74d5fffff      0
# 88195d281dfffff      0
# Name: fail, Length: 144, dtype: int32

# %%
locations = df[df['gexagon']=='88195d2b1dfffff'][['origin_latitude', 'origin_longitude', 'fail']]
locations.head()
# Out:
#     origin_latitude  origin_longitude  fail
# 2         51.455544         -0.969520     0
# 4         51.458236         -0.967605     1
# 22        51.456781         -0.972037     0
# 24        51.458671         -0.973763     0
# 37        51.458022         -0.971564     0

# %%
markers = locations.values

# %%
loc = locations.iloc[0].values
loc
# Out:
# array([51.455544, -0.96952 ,  0.      ])

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      -------------------------------------- 102.3/102.3 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9 in c:\users\marcs\anaconda3\lib\site-packages (from folium) (2.11.3)
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\users\marcs\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: requests in c:\users\marcs\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\marcs\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\marcs\anaconda3\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\marcs\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marcs\anaconda3\lib\site-packages (from requests->folium) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marcs\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0

# %%
#Визуализация
import folium

m = folium.Map(location=[loc[0], loc[1]], zoom_start=15)
for i in markers:
  color = 'blue'
  if i[2] == 1:
    color = 'red'

  folium.CircleMarker(
    location=[i[0], i[1]],
    fill=True,
    fill_color=color,
    color=color,
    radius=1).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f52ae2c9d1976590757966dc3d86d742 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f52ae2c9d1976590757966dc3d86d742&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f52ae2c9d1976590757966dc3d86d742 = L.map(
#                 &quot;map_f52ae2c9d1976590757966dc3d86d742&quot;,
#                 {
#                     center: [51.455544, -0.96952],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c408171c75d58d3d6b601f049ef59e0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f52ae2c9d1976590757966dc3d86d742);
#
#
#             var circle_marker_1410cf83e4425061381ff2faab64eda9 = L.circleMarker(
#                 [51.455544, -0.96952],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f52ae2c9d1976590757966dc3d86d742);
#
#
#             var circle_marker_2c5277392a837bf9aa76d9a70a6708a8 = L.circleMarker(
#                 [51.458236, -0.967605],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f52ae2c9d1976590757966dc3d86d742);
#
#
#             var circle_marker_11d42f8a0c06a9ea005c3020525a06d4 = L.circleMarker(
#                 [51.456781, -0.972037],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f52ae2c9d1976590757966dc3d86d742);
#
#
#             var circle_marker_42e57b5e71a7b3f3d10daf75a29c6f10 = L.circleMarker(
#                 [51.458671, -0.973763],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f52ae2c9d1976590757966dc3d86d742);
#
#
#             var circle_marker_779340e388378a30290b9506e8a4f3a9 = L.circleMarker(
#                 [51.458022, -0.971564],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f52ae2c9d1976590757966dc3d86d742);
#
#
#             var circle_marker_a91b7305140f29bc6069037e70c8cdd1 = L.circleMarker(
#                 [51.456599, -0.975043],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f52ae2c9d1976590757966dc3d86d742);
#
#
#             var circle_marker_413a2e9882b906dfb527eeca3052dda0 = L.circleMarker(
#                 [51.457899, -

# %%
#красные - отклонённые режекты
